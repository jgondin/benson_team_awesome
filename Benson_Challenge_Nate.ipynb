# %% [markdown]
# ## Challenge 1

# %%
# ! curl http://web.mta.info/developers/data/nyct/turnstile/turnstile_160402.txt > 'mta_data.csv'

# %%
import csv

# %%
def read_data(data):
    with open(data, 'r') as f:
        data =[row for row in csv.reader(f.read().splitlines())]
    return data
    
#     i= 0
#     for row in mta:
#         if i == 10:
#             break
#         else:
#             print row
#             i += 1

# %%
mta = read_data('mta_data.csv')

# %%
mta[0]
# Out:
# ['C/A',
#  'UNIT',
#  'SCP',
#  'STATION',
#  'LINENAME',
#  'DIVISION',
#  'DATE',
#  'TIME',
#  'DESC',
#  'ENTRIES',
#  'EXITS                                                               ']

# %%
mta_key = [x[:4] for x in mta]

# %%
mta_key_tup = []
for row in mta_key:
    mta_key_tup.append(tuple(row))

# %%
mta_key_tup[:5]
# Out:
# [('C/A', 'UNIT', 'SCP', 'STATION'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST')]

# %%
mta_values = [x[4:] for x in mta]

# %%
for row in mta_values:
    row[-1] = row[-1].strip()

# %%
mta_values[1]
# Out:
# ['NQR456',
#  'BMT',
#  '03/26/2016',
#  '00:00:00',
#  'REGULAR',
#  '0005595746',
#  '0001893277']

# %%
from collections import defaultdict

# %%
mta_dict = {}
mta_dict = defaultdict(list)
for i,j in zip(mta_key_tup, mta_values):
    mta_dict[i].append(j)

# %%
# mta_dict = {}
# for k,v in mta_key, mta_values

# %%
for i in mta_key_tup[:5]:
    print mta_dict[i]
# Out:
# [['LINENAME', 'DIVISION', 'DATE', 'TIME', 'DESC', 'ENTRIES', 'EXITS']]
# ...

# %%
mta_key_tup[:5]
# Out:
# [('C/A', 'UNIT', 'SCP', 'STATION'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST'),
#  ('A002', 'R051', '02-00-00', '59 ST')]

# %% [markdown]
# ## Challenge 2
