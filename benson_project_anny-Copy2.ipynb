# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""
list_data =[]
list_weeks = ['160102', '160109', '160116','160130','160206','160213',
              '160220','160227','160305','160312','160319','160326','160402']
for u in list_weeks:
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_' + u + '.txt'
    print(url)
    list_data.append(pd.read_csv(url))

data = pd.concat(list_data)
del list_data"""
# Out:
# "\nlist_data =[]\nlist_weeks = ['160102', '160109', '160116','160130','160206','160213',\n              '160220','160227','160305','160312','160319','160326','160402']\nfor u in list_weeks:\n    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_' + u + '.txt'\n    print(url)\n    list_data.append(pd.read_csv(url))\n\ndata = pd.concat(list_data)\ndel list_data"

# %%
data = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160102.txt")

# %%
data.columns = [column.strip() for column in data.columns]
data.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES', u'EXITS'],
#       dtype='object')

# %%
data.rename(columns={"EXITS": "EXIT", "ENTRIES": "ENTRY"}, inplace=True)

# %%
data['dENTRY'] = 0
data['dEXIT'] = 0

# %%
data['dENTRY'] = data.ENTRY.shift(-1) - data.ENTRY
data['dEXIT'] = data.EXIT.shift(-1) - data.EXIT
data['dTOTAL'] = data.dENTRY + data.dEXIT

# %%
#diff = data['ENTRY'].iloc[1:].values - data['ENTRY'].iloc[:-1].values
#data['DENTRY'][1:] = diff
#diff = data['EXIT'].iloc[:-1].values - data['EXIT'].iloc[1:].values
#data['DEXIT'][1:] = diff

# %%
data['DATETIME'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
data['HOUR'] = data['DATETIME'].apply(lambda x: x.hour)

# %%
data['WEEKDAY']=data.DATETIME.apply(lambda x: 'Weekday' if 0<=x.weekday()<5 else 'Weekend')

# %%
daysofweek = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

whatdayofweek = lambda x: daysofweek[x.weekday()]


data['DAYOFWEEK'] = data.DATETIME.apply(whatdayofweek)

# %%
data_cleaned = data[(data['dENTRY'] >= 0) & (data['dENTRY'] <= 5000) & (data['dEXIT'] >= 0) & (data['dEXIT'] <= 5000)]

# %%
data_0to4 = data_cleaned[(data_cleaned.HOUR ==0)|(data_cleaned.HOUR==1)]

# %%
data_0to4
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 504      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/26/2015
# 510      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/27/2015
# 516      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/28/2015
# 522      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/29/2015
# 528      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/30/2015
# 534      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  12/31/2015
# 540      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/01/2016
# 546      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/26/2015
# 552      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/27/2015
# 558      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/28/2015
# 564      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/29/2015
# 570      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/30/2015
# 576      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  12/31/2015
# 582      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/01/2016
# 588      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/26/2015
# 594      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/27/2015
# 600      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/28/2015
# 606      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/29/2015
# 612      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/30/2015
# 618      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  12/31/2015
# 624      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/01/2016
# 630      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/26/2015
# 636      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/27/2015
# 642      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/28/2015
# 648      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/29/2015
# 654      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/30/2015
# 660      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  12/31/2015
# 666      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01
# 191613  00:00:00  REGULAR  1417901    14583      54      2      56
# 191619  00:00:00  REGULAR   272317    11129       0      2       2
# 191625  00:00:00  REGULAR   272576    11137       0      0       0
# 191631  00:00:00  REGULAR   272793    11149       0      1       1
# 191637  00:00:00  REGULAR   273141    11161       1      0       1
# 191643  00:00:00  REGULAR   273357    11165       0      0       0
# 191649  00:00:00  REGULAR   273836    11176       1      1       2
# 191655  00:00:00  REGULAR   274068    11185       3      4       7
# 191661  00:00:00  REGULAR  2583057   375729       0      0       0
# 191667  00:00:00  REGULAR  2583323   375738       0      0       0
# 191673  00:00:00  REGULAR  2583590   375758       0      0       0
# 191679  00:00:00  REGULAR  2583934   375765       1      3       4
# 191685  00:00:00  REGULAR  2584197   375780       0      2       2
# 191691  00:00:00  REGULAR  2584758   375801       1      0       1
# 191697  00:00:00  REGULAR  2585053   375810       4      0       4
# 191703  00:00:00  REGULAR     2049       62       0      0       0
# 191709  00:00:00  REGULAR     2049       62       0      0       0
# 191715  00:00:00  REGULAR     2050       62       0      0       0
# 191721  00:00:00  REGULAR     2050       62       0      0       0
# 191727  00:00:00  REGULAR     2050       62       0      0       0
# 191733  00:00:00  REGULAR     2051       62       0      0       0
# 191739  00:00:00  REGULAR     2051       62       0      0       0
# 191745  00:00:00  REGULAR     5554      230       0      0       0
# 191751  00:00:00  REGULAR     5554      230       0      0       0
# 191757  00:00:00  REGULAR     5554      230       0      0       0
# 191763  00:00:00  REGULAR     5554      230       0      0       0
# 191769  00:00:00  REGULAR     5554      230       0      0       0
# 191775  00:00:00  REGULAR     5554      230       0      0       0
# 191781  00:00:00  REGULAR     5554      230       0      0       0
#
#                   DATETIME  HOUR  WEEKDAY  DAYOFWEEK
# 504    2015-12-26 01:00:00     1  Weekend   Saturday
# 510    2015-12-27 01:00:00     1  Weekend     Sunday
# 516    2015-12-28 01:00:00     1  Weekday     Monday
# 522    2015-12-29 01:00:00     1  Weekday    Tuesday
# 528    2015-12-30 01:00:00     1  Weekday  Wednesday
# 534    2015-12-31 01:00:00     1  Weekday   Thursday
# 540    2016-01-01 01:00:00     1  Weekday     Friday
# 546    2015-12-26 01:00:00     1  Weekend   Saturday
# 552    2015-12-27 01:00:00     1  Weekend     Sunday
# 558    2015-12-28 01:00:00     1  Weekday     Monday
# 564    2015-12-29 01:00:00     1  Weekday    Tuesday
# 570    2015-12-30 01:00:00     1  Weekday  Wednesday
# 576    2015-12-31 01:00:00     1  Weekday   Thursday
# 582    2016-01-01 01:00:00     1  Weekday     Friday
# 588    2015-12-26 01:00:00     1  Weekend   Saturday
# 594    2015-12-27 01:00:00     1  Weekend     Sunday
# 600    2015-12-28 01:00:00     1  Weekday     Monday
# 606    2015-12-29 01:00:00     1  Weekday    Tuesday
# 612    2015-12-30 01:00:00     1  Weekday  Wednesday
# 618    2015-12-31 01:00:00     1  Weekday   Thursday
# 624    2016-01-01 01:00:00     1  Weekday     Friday
# 630    2015-12-26 01:00:00     1  Weekend   Saturday
# 636    2015-12-27 01:00:00     1  Weekend     Sunday
# 642    2015-12-28 01:00:00     1  Weekday     Monday
# 648    2015-12-29 01:00:00     1  Weekday    Tuesday
# 654    2015-12-30 01:00:00     1  Weekday  Wednesday
# 660    2015-12-31 01:00:00     1  Weekday   Thursday
# 666    2016-01-01 01:00:00     1  Weekday     Friday
# 672    2015-12-26 01:00:00     1  Weekend   Saturday
# 678    2015-12-27 01:00:00     1  Weekend     Sunday
# ...                    ...   ...      ...        ...
# 191607 2015-12-31 00:00:00     0  Weekday   Thursday
# 191613 2016-01-01 00:00:00     0  Weekday     Friday
# 191619 2015-12-26 00:00:00     0  Weekend   Saturday
# 191625 2015-12-27 00:00:00     0  Weekend     Sunday
# 191631 2015-12-28 00:00:00     0  Weekday     Monday
# 191637 2015-12-29 00:00:00     0  Weekday    Tuesday
# 191643 2015-12-30 00:00:00     0  Weekday  Wednesday
# 191649 2015-12-31 00:00:00     0  Weekday   Thursday
# 191655 2016-01-01 00:00:00     0  Weekday     Friday
# 191661 2015-12-26 00:00:00     0  Weekend   Saturday
# 191667 2015-12-27 00:00:00     0  Weekend     Sunday
# 191673 2015-12-28 00:00:00     0  Weekday     Monday
# 191679 2015-12-29 00:00:00     0  Weekday    Tuesday
# 191685 2015-12-30 00:00:00     0  Weekday  Wednesday
# 191691 2015-12-31 00:00:00     0  Weekday   Thursday
# 191697 2016-01-01 00:00:00     0  Weekday     Friday
# 191703 2015-12-26 00:00:00     0  Weekend   Saturday
# 191709 2015-12-27 00:00:00     0  Weekend     Sunday
# 191715 2015-12-28 00:00:00     0  Weekday     Monday
# 191721 2015-12-29 00:00:00     0  Weekday    Tuesday
# 191727 2015-12-30 00:00:00     0  Weekday  Wednesday
# 191733 2015-12-31 00:00:00     0  Weekday   Thursday
# 191739 2016-01-01 00:00:00     0  Weekday     Friday
# 191745 2015-12-26 00:00:00     0  Weekend   Saturday
# 191751 2015-12-27 00:00:00     0  Weekend     Sunday
# 191757 2015-12-28 00:00:00     0  Weekday     Monday
# 191763 2015-12-29 00:00:00     0  Weekday    Tuesday
# 191769 2015-12-30 00:00:00     0  Weekday  Wednesday
# 191775 2015-12-31 00:00:00     0  Weekday   Thursday
# 191781 2016-01-01 00:00:00     0  Weekday     Friday
#
# [13485 rows x 18 columns]

# %%
data_grouped = data_0to4.groupby(['DATE','STATION']).sum()

# %%
data_grouped
# Out:
#                                  ENTRY        EXIT  dENTRY  dEXIT  dTOTAL  \
# DATE       STATION
# 01/01/2016 103 ST            124275451    97068537    1382   2627    4009
#            111 ST             56026967    20703956       7      7      14
#            116 ST            434045322   443270013    2226   1544    3770
#            116 ST-COLUMBIA  1209304180   255757907     427    397     824
#            125 ST            149283761   108805385    2122   1930    4052
#            135 ST            202828327    30307064     238    347     585
#            137 ST CITY COL    51595602    40876251     574    970    1544
#            14 ST             263727289    52602844    2026   1126    3152
#            14 ST-UNION SQ   1295825246   498726380    8723   4876   13599
#            14TH STREET         5328286     1390620    1587    197    1784
#            155 ST             30732079    23505411     347    659    1006
#            157 ST             31479360    21130033     598    886    1484
#            163 ST-AMSTERDM    16699135    11278577     143    289     432
#            170 ST           1284544003  2348550148     222    242     464
#            174 ST             21571530    14401105     288    429     717
#            18 AV              20547147    21078948      79    327     406
#            181 ST             51373405    42726742     325   1043    1368
#            20 AV              14549689    12590139      27    181     208
#            21 ST               5581354     6316633     165    191     356
#            219 ST              9570512     5885820     135    104     239
#            225 ST             14065377     7765433     154    135     289
#            23 ST            2188269767  1831047870    2541   2026    4567
#            233 ST             95213634     4508303     150     88     238
#            238 ST             18951764      873664     210     10     220
#            25 AV               3647116     1233446      82    122     204
#            28 ST            1511587521  2315673565    2605   1746    4351
#            3 AV 138 ST        17463359    14917640     271    457     728
#            33 ST             227628017   136211144    1830   1380    3210
#            34 ST-PENN STA   1882266234  1219826448    3421   2279    5700
#            36 ST             863856666  1233230333     475   1153    1628
# ...                                ...         ...     ...    ...     ...
# 12/31/2015 RIT-MANHATTAN       4246923       68972      63      1      64
#            RIT-ROOSEVELT       7181901      443024      25      3      28
#            ROCKAWAY AV       716550294    42260220     102    183     285
#            ROCKAWAY BLVD     271252502    12923252     110    100     210
#            ROCKAWAY PARK B   105075618    10824168      14     49      63
#            SENECA AVE          5064757     5660500      31    134     165
#            SHEEPSHEAD BAY     39503737    35687499     131    356     487
#            SHEPHERD AV        16685992    14330380      52     88     140
#            SIMPSON ST         36994903    10242128     125     45     170
#            SOUTH FERRY        34934820    30590148     181    556     737
#            SUTPHIN BLVD       17864532     9611088      32    127     159
#            SUTPHIN-ARCHER       390518      370327     267    441     708
#            SUTTER AV          11107537    14919689      76    247     323
#            THIRTY ST            788721     3428432      66      9      75
#            THIRTY THIRD ST     5012759     3532470     193    174     367
#            TOMPKINSVILLE       8612291     2414987      10      0      10
#            TREMONT AV        128816996    10654451     153    401     554
#            TWENTY THIRD ST      566901     1196172      34     16      50
#            UTICA AV          102383089    49731798     276    653     929
#            VAN SICLEN AV      12159407    11914781      63    188     251
#            VAN SICLEN AVE     13181214    13691285      50    160     210
#            W 4 ST-WASH SQ    802331670   894987502    2703    812    3515
#            WAKEFIELD/241      16001928    16554856     133    318     451
#            WALL ST           532858827   277634205      77     80     157
#            WEST FARMS SQ     438009515    72769492     165    305     470
#            WHITEHALL S-FRY   131534549    11861096     133    243     376
#            WINTHROP ST        31323378     5530444      77     49     126
#            WOODHAVEN BLVD     54675899    36218673     205    419     624
#            YORK ST            31243732    28674361      89    104     193
#            ZEREGA AV          53468921      461325      27     97     124
#
#                             HOUR
# DATE       STATION
# 01/01/2016 103 ST              0
#            111 ST              0
#            116 ST              0
#            116 ST-COLUMBIA     0
#            125 ST              0
#            135 ST              0
#            137 ST CITY COL     0
#            14 ST               0
#            14 ST-UNION SQ      0
#            14TH STREET         3
#            155 ST              0
#            157 ST              0
#            163 ST-AMSTERDM     0
#            170 ST              0
#            174 ST              0
#            18 AV               0
#            181 ST              0
#            20 AV               0
#            21 ST               0
#            219 ST              0
#            225 ST              0
#            23 ST               0
#            233 ST              0
#            238 ST              0
#            25 AV               0
#            28 ST               0
#            3 AV 138 ST         0
#            33 ST               0
#            34 ST-PENN STA     21
#            36 ST               0
# ...                          ...
# 12/31/2015 RIT-MANHATTAN       0
#            RIT-ROOSEVELT       0
#            ROCKAWAY AV         0
#            ROCKAWAY BLVD       0
#            ROCKAWAY PARK B     0
#            SENECA AVE          0
#            SHEEPSHEAD BAY      0
#            SHEPHERD AV         0
#            SIMPSON ST          0
#            SOUTH FERRY         0
#            SUTPHIN BLVD        0
#            SUTPHIN-ARCHER      0
#            SUTTER AV           0
#            THIRTY ST           7
#            THIRTY THIRD ST     5
#            TOMPKINSVILLE       7
#            TREMONT AV          0
#            TWENTY THIRD ST     0
#            UTICA AV            0
#            VAN SICLEN AV       0
#            VAN SICLEN AVE      0
#            W 4 ST-WASH SQ      0
#            WAKEFIELD/241       0
#            WALL ST            28
#            WEST FARMS SQ       0
#            WHITEHALL S-FRY     0
#            WINTHROP ST         0
#            WOODHAVEN BLVD      0
#            YORK ST             0
#            ZEREGA AV           0
#
# [1390 rows x 6 columns]

# %%
data_reset = (data_grouped
    .reset_index()
    .sort_values(['dTOTAL'], ascending=(False))
)
data_reset
# Out:
#             DATE          STATION       ENTRY        EXIT  dENTRY  dEXIT  \
# 8     01/01/2016   14 ST-UNION SQ  1295825246   498726380    8723   4876
# 30    01/01/2016  42 ST-PORT AUTH   323071716    86045730    8131   2395
# 190   01/01/2016   W 4 ST-WASH SQ   802362012   895020261    6303   3384
# 51    01/01/2016            96 ST   769817980  1415871614    2627   4528
# 45    01/01/2016             8 AV   197136435    90764301    4927   2061
# 91    01/01/2016   DELANCEY/ESSEX  1710769774  1110982848    4302   2299
# 41    01/01/2016             7 AV  1907910719   838925819    4771   1808
# 42    01/01/2016            72 ST  1607584159   983008486    4535   1967
# 28    01/01/2016   34 ST-PENN STA  1882266234  1219826448    3421   2279
# 406   12/27/2015   14 ST-UNION SQ  1298639282   502382002    3837   1139
# 1200  12/31/2015   14 ST-UNION SQ  1295748794   498653448    3634   1149
# 21    01/01/2016            23 ST  2188269767  1831047870    2541   2026
# 77    01/01/2016         CANAL ST  2982847741  1621189329    2592   1861
# 112   01/01/2016  GRD CNTRL-42 ST  2645123108   624410165    1369   3070
# 25    01/01/2016            28 ST  1511587521  2315673565    2605   1746
# 1002  12/30/2015   14 ST-UNION SQ  1295653043   498567996    3245    986
# 4     01/01/2016           125 ST   149283761   108805385    2122   1930
# 0     01/01/2016           103 ST   124275451    97068537    1382   2627
# 41      6579     0
# 42      6502     0
# 28      5700    21
# 406     4976     0
# 1200    4783     0
# 21      4567     0
# 77      4453     0
# 112     4439     0
# 25      4351     0
# 1002    4231     0
# 4       4052     0
# 0       4009     0
# 428     3786    19
# 2       3770     0
# 587     3690     0
# 1381    3515     0
# 139     3360     0
# 35      3279     0
# 48      3247     0
# 56      3215     0
# 27      3210     0
# 803     3171     0
# 43      3168     0
# 7       3152     0
# ...      ...   ...
# 941       17     0
# 1058      17     0
# 1140      16     0
# 965       16     0
# 544       16     0
# 678       14     0
# 1         14     0
# 514       14     1
# 468       14     0
# 581       13     7
# 660       13     0
# 859       13     0
# 865       13     0
# 462       13     0
# 1343      13     6
# 263       12     0
# 1375      10     7
# 780       10     7
# 946        9     1
# 979        9     7
# 1262       8     0
# 269        8     0
# 1177       7     7
# 666        5     0
# 383        4     7
# 1179       3     1
# 151        3     7
# 549        0     2
# 350        0     0
# 1145       0     0
#
# [1390 rows x 8 columns]

# %%
for r in range(data_reset.shape[0]):
    if data_reset.ix[r,'WEEKDAY'] =='Weekday':
        data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(5)
    else:
        data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-34b486508461> in <module>()
#       1 for r in range(data_reset.shape[0]):
# ----> 2     if data_reset.ix[r,'WEEKDAY'] =='Weekday':
#       3         data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(5)
#       4     else:
#       5         data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(2)
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      66                 pass
#      67
# ---> 68             return self._getitem_tuple(key)
#      69         else:
#      70             return self._getitem_axis(key, axis=0)
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     736     def _getitem_tuple(self, tup):
#     737         try:
# --> 738             return self._getitem_lowerdim(tup)
#     739         except IndexingError:
#     740             pass
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     886
#     887                 # This is an elided recursive call to iloc/loc/etc'
# --> 888                 return getattr(section, self.name)[new_key]
#     889
#     890         raise IndexingError('not applicable')
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     965                     return self._get_loc(key, axis=axis)
#     966
# --> 967             return self._get_label(key, axis=axis)
#     968
#     969     def _getitem_iterable(self, key, axis=0):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_label(self, label, axis)
#      79                 return self.obj._xs(label, axis=axis)
#      80             except:
# ---> 81                 return self.obj[label]
#      82         elif (isinstance(label, tuple) and
#      83                 isinstance(label[axis], slice)):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     555     def __getitem__(self, key):
#     556         try:
# --> 557             result = self.index.get_value(self, key)
#     558
#     559             if not np.isscalar(result):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1802                     raise InvalidIndexError(key)
#    1803                 else:
# -> 1804                     raise e1
#    1805             except Exception:  # pragma: no cover
#    1806                 raise e1
#
# KeyError: 'WEEKDAY'

# %%
data_reset

# %%
testweekend = data_reset[(data_reset.WEEKDAY == 'Weekday')]

# %%
testweekend

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data_reset[data_reset.STATION=='WORLD TRADE CTR'].dTOTAL.plot(kind='bar');
data_reset[data_reset.STATION=='WORLD TRADE CTR'].hist(by = data_reset.DATE, bins = 25, figsize = (100,50));
