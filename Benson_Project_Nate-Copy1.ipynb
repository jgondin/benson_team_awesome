# %%
import csv
import urllib
import io
import pandas as pd
data = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_160326.txt')

# %%
data.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  03/19/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  03/19/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  03/19/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  03/19/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  03/19/2016  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  5590801
# 1  REGULAR  5590828
# 2  REGULAR  5590852
# 3  REGULAR  5590958
# 4  REGULAR  5591207
#
#    EXITS
# 0                                            1889027
# 1                                            1889032
# 2                                            1889059
# 3                                            1889162
# 4                                            1889248

# %%
data.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES',
#        u'EXITS                                                               '],
#       dtype='object')

# %%
data.rename(columns={data.columns[-1]: data.columns[-1].replace(' ','')}, inplace=True)
data.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES', u'EXITS'],
#       dtype='object')

# %%
data['Delta'] = abs((data['ENTRIES'] - data['ENTRIES'].shift(-1)) + (data['EXITS'] - data['EXITS'].shift(-1)))

# %%
test = data.sort_values(['Delta'])
test.tail(4000)
# Out:
#           C/A  UNIT       SCP          STATION     LINENAME DIVISION  \
# 120735   R113  R028  01-06-00        FULTON ST     2345ACJZ      IRT
# 25993    E004  R234  00-00-00            50 ST            D      BMT
# 33485    H038  R350  00-00-00       LIVONIA AV            L      BMT
# 78372    N317  R267  02-06-00            46 ST           MR      IND
# 79961   N325A  R218  00-00-01      ELMHURST AV           MR      IND
# 152107   R246  R177  00-00-04   68ST-HUNTER CO            6      IRT
# 67240    N185  R417  00-05-01      BEACH 98 ST           AS      IND
# 125543   R138  R293  00-00-00   34 ST-PENN STA       123ACE      IRT
# 90508   N420B  R317  00-00-01  CLINTON-WASH AV            G      IND
# 28516    G015  R312  01-05-01  W 8 ST-AQUARIUM           FQ      BMT
# 108339  PTH02  R544  00-04-02         HARRISON            1      PTH
# 135891   R180  R193  00-00-03           157 ST            1      IRT
# 115932  PTH16  R550  01-02-04       LACKAWANNA            1      PTH
# 2927     A021  R032  01-00-05   TIMES SQ-42 ST  ACENQRS1237      BMT
# 114040  PTH11  R545  00-04-05      14TH STREET            1      PTH
# 10470    A060  R001  00-00-02  WHITEHALL S-FRY           R1      BMT
# 36614    J012  R379  00-00-01    KOSCIUSZKO ST            J      BMT
# 12524    A083  R125  00-00-01         BROAD ST           JZ      BMT
# 38718    J035  R008  00-00-01           111 ST            J      BMT
# 173137   R515  R095  00-00-02  ASTORIA DITMARS           NQ      BMT
# 184042   R610  R057  00-06-03   ATL AV-BARCLAY    2345BDNQR      IRT
# 166014   R406  R448  00-00-01  E 143/ST MARY'S            6      IRT
# 118158  PTH20  R549  03-00-05     NEWARK HM HE            1      PTH
# 144154   R226  R131  02-03-00            23 ST            6      IRT
# 116768  PTH18  R549  01-00-03     NEWARK BM BW            1      PTH
# 21948    C017  R455  00-00-02            25 ST            R      BMT
# 12104    A081  R028  04-00-02        FULTON ST     ACJZ2345      BMT
# 14117    B015  R098  01-00-02        CHURCH AV           BQ      BMT
# 178184   R532  R328  00-05-03  METS-WILLETS PT            7      IRT
# 36782    J013  R380  00-00-02         GATES AV           JZ      BMT
# ...       ...   ...       ...              ...          ...      ...
# 127212   R143  R032  02-03-02   TIMES SQ-42 ST  1237ACENQRS      IRT
# 44483    N029  R333  01-00-02           116 ST           BC      IND
# 70349    N208  R443  01-05-01           170 ST           BD      IND
# 95299    N508  R453  00-00-02            23 ST           FM      IND
# 92769    N502  R021  01-00-03  42 ST-BRYANT PK        BDFM7      IND
# 92813    N502  R021  01-00-04  42 ST-BRYANT PK        BDFM7      IND
# 131409  R161A  R452  01-06-02            72 ST          123      IRT
# 131365  R161A  R452  01-06-01            72 ST          123      IRT
# 160735   R310  R053  01-00-01      3 AV-149 ST           25      IRT
# 160777   R310  R053  01-00-02      3 AV-149 ST           25      IRT
# 50026   N063A  R011  00-00-06  42 ST-PORT AUTH  ACENQRS1237      IND
# 145217   R228  R143  00-00-01            28 ST            6      IRT
# 145175   R228  R143  00-00-00            28 ST            6      IRT
# 128048   R148  R033  01-00-00   TIMES SQ-42 ST  1237ACENQRS      IRT
# 128090   R148  R033  01-00-01   TIMES SQ-42 ST  1237ACENQRS      IRT
# 148640  R238A  R046  02-00-02  GRD CNTRL-42 ST        4567S      IRT
# 148682  R238A  R046  02-00-03  GRD CNTRL-42 ST        4567S      IRT
# 144112   R226  R131  02-00-00            23 ST            6      IRT
# 144070   R221  R170  01-06-03   14 ST-UNION SQ      456LNQR      IRT
# 3515     A025  R023  01-03-02  34 ST-HERALD SQ      BDFMNQR      BMT
# 3473     A025  R023  01-03-01  34 ST-HERALD SQ      BDFMNQR      BMT
# 157770   R287  R244  00-06-00      BURNSIDE AV            4      IRT
# 157812   R288  R275  00-00-00           183 ST            4      IRT
# 48514    N062  R011  01-00-00  42 ST-PORT AUTH  ACENQRS1237      IND
# 48556    N062  R011  01-00-01  42 ST-PORT AUTH  ACENQRS1237      IND
# 121283   R116  R030  00-00-01      CHAMBERS ST          123      IRT
# 121326   R116  R030  00-00-02      CHAMBERS ST          123      IRT
# 35985    J005  R353  00-00-00       LORIMER ST           JM      BMT
# 36026    J005  R353  00-00-01       LORIMER ST           JM      BMT
# 192945  TRAM2  R469  00-05-01    RIT-ROOSEVELT            R      RIT
#
#               DATE      TIME     DESC     ENTRIES       EXITS         Delta
# 120735  03/25/2016  23:00:00  REGULAR      740221     1900865  3.303660e+05
# 131365  03/25/2016  21:00:00  REGULAR     7602308     4637128  3.140775e+09
# 160735  03/25/2016  20:00:00  REGULAR     6640131      762375  3.179582e+09
# 160777  03/25/2016  20:00:00  REGULAR  1945335259  1241633203  3.182698e+09
# 50026   03/25/2016  20:00:00  REGULAR  1410994628  1829106673  3.209087e+09
# 145217  03/25/2016  21:00:00  REGULAR  1426964970  1879752066  3.296276e+09
# 145175  03/25/2016  21:00:00  REGULAR     2061721     3651233  3.300982e+09
# 128048  03/25/2016  20:00:00  REGULAR     6922514     9132820  3.305303e+09
# 128090  03/25/2016  20:00:00  REGULAR  1894392250  1426961215  3.316519e+09
# 148640  03/25/2016  20:00:00  REGULAR     1769926      104882  3.487541e+09
# 148682  03/25/2016  20:00:00  REGULAR  2146696604  1342719068  3.489416e+09
# 144112  03/25/2016  21:00:00  REGULAR  1996840688  1544245833  3.519614e+09
# 144070  03/25/2016  21:00:00  REGULAR     4584525     1280482  3.535198e+09
# 3515    03/25/2016  20:00:00  REGULAR  1557587682  2048391526  3.576123e+09
# 3473    03/25/2016  20:00:00  REGULAR    11032107     6671905  3.588286e+09
# 157770  03/25/2016  20:00:00  REGULAR     1976968     4700948  3.636779e+09
# 157812  03/25/2016  20:00:00  REGULAR  1779727741  1863747643  3.639757e+09
# 48514   03/25/2016  20:00:00  REGULAR     9887550    34673691  3.679747e+09
# 48556   03/25/2016  20:00:00  REGULAR  2031474928  1692830391  3.718153e+09
# 121283  03/25/2016  20:00:00  REGULAR     9999494    11087830  3.805322e+09
# 121326  03/25/2016  20:00:00  REGULAR  2114628307  1711796106  3.816414e+09
# 35985   03/25/2016  21:00:00  REGULAR     4106135     1342499  4.222466e+09
# 36026   03/25/2016  21:00:00  REGULAR  2130756393  2097166165  4.225224e+09
# 192945  03/25/2016  21:00:00  REGULAR        5554         236           NaN
#
# [4000 rows x 12 columns]

# %%
if data[data['STATION'] =='50 ST']:
#if data['STATION']==data['STATION'].shift(-1):
    #if data['SCP']==data['SCP'].shift(-1):
    data['Delta'] = abs((data['ENTRIES'] - data['ENTRIES'].shift(-1)) + (data['EXITS'] - data['EXITS'].shift(-1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-35dfeafaa78e> in <module>()
# ----> 1 if data[data['STATION'] =='50 ST'] == True:
#       2 #if data['STATION']==data['STATION'].shift(-1):
#       3     #if data['SCP']==data['SCP'].shift(-1):
#       4     data['Delta'] = abs((data['ENTRIES'] - data['ENTRIES'].shift(-1)) + (data['EXITS'] - data['EXITS'].shift(-1)))
#
# /Users/anthonykim/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     885         raise ValueError("The truth value of a {0} is ambiguous. "
#     886                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 887                          .format(self.__class__.__name__))
#     888
#     889     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_night = data[data['TIME' ==  ]
