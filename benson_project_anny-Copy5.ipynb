# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""
list_data =[]
list_weeks = ['160102', '160109', '160116','160130','160206','160213',
              '160220','160227','160305','160312','160319','160326','160402']
for u in list_weeks:
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_' + u + '.txt'
    print(url)
    list_data.append(pd.read_csv(url))

data = pd.concat(list_data)
del list_data"""
# Out:
# "\nlist_data =[]\nlist_weeks = ['160102', '160109', '160116','160130','160206','160213',\n              '160220','160227','160305','160312','160319','160326','160402']\nfor u in list_weeks:\n    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_' + u + '.txt'\n    print(url)\n    list_data.append(pd.read_csv(url))\n\ndata = pd.concat(list_data)\ndel list_data"

# %%
data = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160130.txt")

# %%
data.columns = [column.strip() for column in data.columns]
data.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES', u'EXITS'],
#       dtype='object')

# %%
data.rename(columns={"EXITS": "EXIT", "ENTRIES": "ENTRY"}, inplace=True)

# %%
data['dENTRY'] = 0
data['dEXIT'] = 0

# %%
data['dENTRY'] = data.ENTRY.shift(-1) - data.ENTRY
data['dEXIT'] = data.EXIT.shift(-1) - data.EXIT
data['dTOTAL'] = data.dENTRY + data.dEXIT

# %%
#diff = data['ENTRY'].iloc[1:].values - data['ENTRY'].iloc[:-1].values
#data['DENTRY'][1:] = diff
#diff = data['EXIT'].iloc[:-1].values - data['EXIT'].iloc[1:].values
#data['DEXIT'][1:] = diff

# %%
data['DATETIME'] = pd.to_datetime(data.DATE + data.TIME, format='%m/%d/%Y%H:%M:%S')
data['HOUR'] = data['DATETIME'].apply(lambda x: x.hour)

# %%
data['WEEKDAY']=data.DATETIME.apply(lambda x: 'Weekday' if 0<=x.weekday()<5 else 'Weekend')

# %%
daysofweek = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

whatdayofweek = lambda x: daysofweek[x.weekday()]


data['DAYOFWEEK'] = data.DATETIME.apply(whatdayofweek)

# %%
data_cleaned = data[(data['dENTRY'] >= 0) & (data['dENTRY'] <= 5000) & (data['dEXIT'] >= 0) & (data['dEXIT'] <= 5000)]

# %%
data_0to4 = data_cleaned[(data_cleaned.HOUR ==0)|(data_cleaned.HOUR==1)]

# %%
data_0to4
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 503      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/23/2016
# 509      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/24/2016
# 515      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/25/2016
# 521      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/26/2016
# 527      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/27/2016
# 533      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/28/2016
# 539      A006  R079  00-00-00     5 AV/59 ST      NQR      BMT  01/29/2016
# 545      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/23/2016
# 551      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/24/2016
# 557      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/25/2016
# 563      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/26/2016
# 569      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/27/2016
# 575      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/28/2016
# 581      A006  R079  00-00-01     5 AV/59 ST      NQR      BMT  01/29/2016
# 587      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/23/2016
# 593      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/24/2016
# 599      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/25/2016
# 605      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/26/2016
# 611      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/27/2016
# 617      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/28/2016
# 623      A006  R079  00-00-02     5 AV/59 ST      NQR      BMT  01/29/2016
# 629      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/23/2016
# 635      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/24/2016
# 641      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/25/2016
# 647      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/26/2016
# 653      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/27/2016
# 659      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/28/2016
# 665      A006  R079  00-00-03     5 AV/59 ST      NQR      BMT  01/29/2016
# 671      A006  R079  00-00-04     5 AV/59 ST      NQR      BMT  01/23/2016
# 677      A006  R079  00-00-04     5 AV/59 ST      NQR      BMT  01/24/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193564  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT
# 193576  00:00:00  REGULAR   278290    11371       1      2       3
# 193582  00:00:00  REGULAR   278298    11391       0      0       0
# 193588  00:00:00  REGULAR   278398    11394       0      2       2
# 193594  00:00:00  REGULAR   278507    11399       2      0       2
# 193601  00:00:00  REGULAR   278634    11401       1      0       1
# 193607  00:00:00  REGULAR   278771    11405       0      1       1
# 193613  00:00:00  REGULAR   278910    11407       0      0       0
# 193619  00:00:00  REGULAR  2590053   376052       1      0       1
# 193625  00:00:00  REGULAR  2590056   376069       0      0       0
# 193631  00:00:00  REGULAR  2590151   376073       0      0       0
# 193637  00:00:00  REGULAR  2590288   376077       0      2       2
# 193644  00:00:00  REGULAR  2590429   376089       1      2       3
# 193650  00:00:00  REGULAR  2590621   376097       1      0       1
# 193656  00:00:00  REGULAR  2590790   376103       1      0       1
# 193662  00:00:00  REGULAR     2073       62       0      0       0
# 193668  00:00:00  REGULAR     2073       62       0      0       0
# 193674  00:00:00  REGULAR     2073       62       0      0       0
# 193680  00:00:00  REGULAR     2073       62       0      0       0
# 193687  00:00:00  REGULAR     2073       62       0      0       0
# 193693  00:00:00  REGULAR     2075       62       0      0       0
# 193699  00:00:00  REGULAR     2075       62       0      0       0
# 193705  00:00:00  REGULAR     5554      231       0      0       0
# 193711  00:00:00  REGULAR     5554      231       0      0       0
# 193717  00:00:00  REGULAR     5554      231       0      0       0
# 193723  00:00:00  REGULAR     5554      231       0      0       0
# 193730  00:00:00  REGULAR     5554      231       0      0       0
# 193736  00:00:00  REGULAR     5554      231       0      0       0
# 193742  00:00:00  REGULAR     5554      231       0      0       0
#
#                   DATETIME  HOUR  WEEKDAY  DAYOFWEEK
# 503    2016-01-23 01:00:00     1  Weekend   Saturday
# 509    2016-01-24 01:00:00     1  Weekend     Sunday
# 515    2016-01-25 01:00:00     1  Weekday     Monday
# 521    2016-01-26 01:00:00     1  Weekday    Tuesday
# 527    2016-01-27 01:00:00     1  Weekday  Wednesday
# 533    2016-01-28 01:00:00     1  Weekday   Thursday
# 539    2016-01-29 01:00:00     1  Weekday     Friday
# 545    2016-01-23 01:00:00     1  Weekend   Saturday
# 551    2016-01-24 01:00:00     1  Weekend     Sunday
# 557    2016-01-25 01:00:00     1  Weekday     Monday
# 563    2016-01-26 01:00:00     1  Weekday    Tuesday
# 569    2016-01-27 01:00:00     1  Weekday  Wednesday
# 575    2016-01-28 01:00:00     1  Weekday   Thursday
# 581    2016-01-29 01:00:00     1  Weekday     Friday
# 587    2016-01-23 01:00:00     1  Weekend   Saturday
# 593    2016-01-24 01:00:00     1  Weekend     Sunday
# 599    2016-01-25 01:00:00     1  Weekday     Monday
# 605    2016-01-26 01:00:00     1  Weekday    Tuesday
# 611    2016-01-27 01:00:00     1  Weekday  Wednesday
# 617    2016-01-28 01:00:00     1  Weekday   Thursday
# 623    2016-01-29 01:00:00     1  Weekday     Friday
# 629    2016-01-23 01:00:00     1  Weekend   Saturday
# 635    2016-01-24 01:00:00     1  Weekend     Sunday
# 641    2016-01-25 01:00:00     1  Weekday     Monday
# 647    2016-01-26 01:00:00     1  Weekday    Tuesday
# 653    2016-01-27 01:00:00     1  Weekday  Wednesday
# 659    2016-01-28 01:00:00     1  Weekday   Thursday
# 665    2016-01-29 01:00:00     1  Weekday     Friday
# 671    2016-01-23 01:00:00     1  Weekend   Saturday
# 677    2016-01-24 01:00:00     1  Weekend     Sunday
# ...                    ...   ...      ...        ...
# 193564 2016-01-28 00:00:00     0  Weekday   Thursday
# 193570 2016-01-29 00:00:00     0  Weekday     Friday
# 193576 2016-01-23 00:00:00     0  Weekend   Saturday
# 193582 2016-01-24 00:00:00     0  Weekend     Sunday
# 193588 2016-01-25 00:00:00     0  Weekday     Monday
# 193594 2016-01-26 00:00:00     0  Weekday    Tuesday
# 193601 2016-01-27 00:00:00     0  Weekday  Wednesday
# 193607 2016-01-28 00:00:00     0  Weekday   Thursday
# 193613 2016-01-29 00:00:00     0  Weekday     Friday
# 193619 2016-01-23 00:00:00     0  Weekend   Saturday
# 193625 2016-01-24 00:00:00     0  Weekend     Sunday
# 193631 2016-01-25 00:00:00     0  Weekday     Monday
# 193637 2016-01-26 00:00:00     0  Weekday    Tuesday
# 193644 2016-01-27 00:00:00     0  Weekday  Wednesday
# 193650 2016-01-28 00:00:00     0  Weekday   Thursday
# 193656 2016-01-29 00:00:00     0  Weekday     Friday
# 193662 2016-01-23 00:00:00     0  Weekend   Saturday
# 193668 2016-01-24 00:00:00     0  Weekend     Sunday
# 193674 2016-01-25 00:00:00     0  Weekday     Monday
# 193680 2016-01-26 00:00:00     0  Weekday    Tuesday
# 193687 2016-01-27 00:00:00     0  Weekday  Wednesday
# 193693 2016-01-28 00:00:00     0  Weekday   Thursday
# 193699 2016-01-29 00:00:00     0  Weekday     Friday
# 193705 2016-01-23 00:00:00     0  Weekend   Saturday
# 193711 2016-01-24 00:00:00     0  Weekend     Sunday
# 193717 2016-01-25 00:00:00     0  Weekday     Monday
# 193723 2016-01-26 00:00:00     0  Weekday    Tuesday
# 193730 2016-01-27 00:00:00     0  Weekday  Wednesday
# 193736 2016-01-28 00:00:00     0  Weekday   Thursday
# 193742 2016-01-29 00:00:00     0  Weekday     Friday
#
# [13631 rows x 18 columns]

# %%
data_grouped = data_0to4.groupby(['DATE','STATION']).sum()

# %%
data_grouped
# Out:
#                                  ENTRY        EXIT  dENTRY  dEXIT  dTOTAL  \
# DATE       STATION
# 01/23/2016 103 ST            150481729   593152389     536   1061    1597
#            111 ST             56034725    20707009       5      7      12
#            116 ST            434699946   443606837     672    897    1569
#            116 ST-COLUMBIA  1209538396   255877048     308    198     506
#            125 ST            149985358   109337393     870    949    1819
#            135 ST            202922219    30378536      68    183     251
#            137 ST CITY COL    51836195    41048376     178    661     839
#            14 ST             264095354    52919122     984    322    1306
#            14 ST-UNION SQ   1292952833   498925989    4335   1394    5729
#            14TH STREET         1935210     1494398      34     70     104
#            155 ST             30857781    23586293     108    336     444
#            157 ST             31691860    21276091     189    645     834
#            163 ST-AMSTERDM    16765017    11304547      61    147     208
#            170 ST           1284678548  2348616193      73    178     251
#            174 ST             21690102    14506081     105    295     400
#            18 AV              20620142    21161968      11    144     155
#            181 ST             51584761    42898547      99    443     542
#            20 AV              14606785    12620760       9     25      34
#            21 ST               5614564     6353566     115     94     209
#            219 ST              9635357     5915276      56     77     133
#            225 ST             10706632     6333551      59    118     177
#            23 ST            2188969310  1831620784    1013    346    1359
#            233 ST             95315976     4540882      75     65     140
#            238 ST             19026360      875499      67      5      72
#            25 AV               3745297     1259154      58     90     148
#            28 ST            1512259201  2082324181    1194    469    1663
#            3 AV 138 ST        17609475    15022903     175    387     562
#            33 ST             345633521   136650243     798    338    1136
#            34 ST-PENN STA   1883260585  1220534187     586    389     975
#            36 ST              58871994   159679597     279    563     842
# ...                                ...         ...     ...    ...     ...
# 01/29/2016 RIT-MANHATTAN       2471837       28649      47      1      48
#            RIT-ROOSEVELT       7270661      444674      19      3      22
#            ROCKAWAY AV       716688051    42340205      80    215     295
#            ROCKAWAY BLVD     271419090    12975346      96    102     198
#            ROCKAWAY PARK B   105089820    10843016      15     32      47
#            SENECA AVE          5130401     5723786      28    112     140
#            SHEEPSHEAD BAY     39826804    35976826     148    342     490
#            SHEPHERD AV        16768163    14374801      51    137     188
#            SIMPSON ST         37233686    10281237     113     42     155
#            SOUTH FERRY        35198058    30914860     116    346     462
#            SUTPHIN BLVD       17974984     9677981      39    126     165
#            SUTPHIN-ARCHER       540931      534336     164    281     445
#            SUTTER AV          10704715    14845979      73    176     249
#            THIRTY ST           4731774     6408871     126     61     187
#            THIRTY THIRD ST    12288643     8021956     374    215     589
#            TOMPKINSVILLE       8629719     2414988      15      0      15
#            TREMONT AV        129058039    10799773     164    410     574
#            TWENTY THIRD ST     4486825     1569801      81     63     144
#            UTICA AV          102764984    50013219     251    568     819
#            VAN SICLEN AV      12231878    11987582      41    113     154
#            VAN SICLEN AVE     13259908    13762925      45    158     203
#            W 4 ST-WASH SQ    803320252   895935150    2097    612    2709
#            WAKEFIELD/241      16127849    16684742      98    243     341
#            WALL ST           533345659   278004304      93    113     206
#            WEST FARMS SQ     438199011    72900832     161    226     387
#            WHITEHALL S-FRY   265581870    62305751     157    153     310
#            WINTHROP ST        31493430     5570560      63     30      93
#            WOODHAVEN BLVD     55215877    36536100     170    361     531
#            YORK ST            31465708    28837154     119     84     203
#            ZEREGA AV          53528485      516929      29     83     112
#
#                             HOUR
# DATE       STATION
# 01/23/2016 103 ST              0
#            111 ST              0
#            116 ST              0
#            116 ST-COLUMBIA     0
#            125 ST              0
#            135 ST              0
#            137 ST CITY COL     0
#            14 ST               0
#            14 ST-UNION SQ      0
#            14TH STREET         2
#            155 ST              0
#            157 ST              0
#            163 ST-AMSTERDM     0
#            170 ST              0
#            174 ST              0
#            18 AV               0
#            181 ST              0
#            20 AV               0
#            21 ST               0
#            219 ST              0
#            225 ST              0
#            23 ST               0
#            233 ST              0
#            238 ST              0
#            25 AV               0
#            28 ST               0
#            3 AV 138 ST         0
#            33 ST               0
#            34 ST-PENN STA     21
#            36 ST               0
# ...                          ...
# 01/29/2016 RIT-MANHATTAN       0
#            RIT-ROOSEVELT       0
#            ROCKAWAY AV         0
#            ROCKAWAY BLVD       0
#            ROCKAWAY PARK B     0
#            SENECA AVE          0
#            SHEEPSHEAD BAY      0
#            SHEPHERD AV         0
#            SIMPSON ST          0
#            SOUTH FERRY         0
#            SUTPHIN BLVD        0
#            SUTPHIN-ARCHER      0
#            SUTTER AV           0
#            THIRTY ST           5
#            THIRTY THIRD ST     2
#            TOMPKINSVILLE       7
#            TREMONT AV          0
#            TWENTY THIRD ST     4
#            UTICA AV            0
#            VAN SICLEN AV       0
#            VAN SICLEN AVE      0
#            W 4 ST-WASH SQ      0
#            WAKEFIELD/241       0
#            WALL ST            28
#            WEST FARMS SQ       0
#            WHITEHALL S-FRY     0
#            WINTHROP ST         0
#            WOODHAVEN BLVD      0
#            YORK ST             0
#            ZEREGA AV           0
#
# [1386 rows x 6 columns]

# %%
data_reset = (data_grouped
    .reset_index()
    .sort_values(['dTOTAL'], ascending=(False))
)
data_reset
# Out:
#             DATE          STATION       ENTRY        EXIT  dENTRY  dEXIT  \
# 8     01/23/2016   14 ST-UNION SQ  1292952833   498925989    4335   1394
# 188   01/23/2016   W 4 ST-WASH SQ   803120959   895749505    3373    875
# 1195  01/29/2016   14 ST-UNION SQ  1293432512   499338030    3095   1086
# 997   01/28/2016   14 ST-UNION SQ  1293324591   499244539    2436    715
# 45    01/23/2016             8 AV   197807335    91265275    2158    825
# 801   01/27/2016   14 ST-UNION SQ  1293216091   499151646    2303    630
# 90    01/23/2016   DELANCEY/ESSEX  1709167341  1109987652    2014    795
# 51    01/23/2016            96 ST   771015378  1416680170    1088   1644
# 1377  01/29/2016   W 4 ST-WASH SQ   803320252   895935150    2097    612
# 602   01/26/2016   14 ST-UNION SQ  1293109769   499060007    1878    574
# 30    01/23/2016  42 ST-PORT AUTH   320634453    99711099    1864    526
# 980   01/27/2016   W 4 ST-WASH SQ   803230319   895850674    1602    565
# 1278  01/29/2016   DELANCEY/ESSEX  1711380984  1111481048     979   1160
# 1178  01/28/2016   W 4 ST-WASH SQ   803274446   895891677    1621    511
# 42    01/23/2016            72 ST  1608316363   983649007    1596    532
# 1232  01/29/2016             8 AV   197976754    91381500    1489    505
# 1080  01/28/2016   DELANCEY/ESSEX  1711355356  1111460667     737   1222
# 883   01/27/2016   DELANCEY/ESSEX  1711330587  1111441482     726   1203
# 51      2732     0
# 1377    2709     0
# 602     2452     0
# 30      2390    18
# 980     2167     0
# 1278    2139     0
# 1178    2132     0
# 42      2128     0
# 1232    1994     0
# 1080    1959     0
# 883     1929     0
# 1238    1869     0
# 849     1845     0
# 784     1836     0
# 4       1819     0
# 403     1741     0
# 205     1735     0
# 1040    1728     0
# 111     1724     0
# 844     1692     0
# 25      1663     0
# 41      1604     0
# 1217    1599    19
# ...      ...   ...
# 246        1     0
# 365        1     0
# 1338       1     4
# 362        1     0
# 237        1     0
# 358        1     0
# 547        0     2
# 321        0     0
# 546        0    11
# 548        0     1
# 575        0     0
# 511        0     1
# 300        0     0
# 211        0     0
# 243        0     0
# 376        0     0
# 214        0     0
# 260        0     0
# 774        0     0
# 373        0     0
# 370        0     0
# 250        0     0
# 745        0     1
# 746        0     2
# 348        0     2
# 349        0     8
# 350        0     5
# 150        0     1
# 366        0     0
# 212        0     0
#
# [1386 rows x 8 columns]

# %%
for r in range(data_reset.shape[0]):
    if data_reset.ix[r,'WEEKDAY'] =='Weekday':
        data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(5)
    else:
        data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-34b486508461> in <module>()
#       1 for r in range(data_reset.shape[0]):
# ----> 2     if data_reset.ix[r,'WEEKDAY'] =='Weekday':
#       3         data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(5)
#       4     else:
#       5         data_reset.ix[r,'dTOTALACTUAL'] = data_reset.ix[r, 'dTOTAL']/(2)
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      66                 pass
#      67
# ---> 68             return self._getitem_tuple(key)
#      69         else:
#      70             return self._getitem_axis(key, axis=0)
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     736     def _getitem_tuple(self, tup):
#     737         try:
# --> 738             return self._getitem_lowerdim(tup)
#     739         except IndexingError:
#     740             pass
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     886
#     887                 # This is an elided recursive call to iloc/loc/etc'
# --> 888                 return getattr(section, self.name)[new_key]
#     889
#     890         raise IndexingError('not applicable')
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     965                     return self._get_loc(key, axis=axis)
#     966
# --> 967             return self._get_label(key, axis=axis)
#     968
#     969     def _getitem_iterable(self, key, axis=0):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_label(self, label, axis)
#      79                 return self.obj._xs(label, axis=axis)
#      80             except:
# ---> 81                 return self.obj[label]
#      82         elif (isinstance(label, tuple) and
#      83                 isinstance(label[axis], slice)):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     555     def __getitem__(self, key):
#     556         try:
# --> 557             result = self.index.get_value(self, key)
#     558
#     559             if not np.isscalar(result):
#
# /Users/annytruong/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1802                     raise InvalidIndexError(key)
#    1803                 else:
# -> 1804                     raise e1
#    1805             except Exception:  # pragma: no cover
#    1806                 raise e1
#
# KeyError: 'WEEKDAY'

# %%
data_reset

# %%
testweekend = data_reset[(data_reset.WEEKDAY == 'Weekday')]

# %%
testweekend

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data_reset[data_reset.STATION=='WORLD TRADE CTR'].dTOTAL.plot(kind='bar');
data_reset[data_reset.STATION=='WORLD TRADE CTR'].hist(by = data_reset.DATE, bins = 25, figsize = (100,50));
